# %%
import os
import sys
import pandas as pd

PROJECT_ROOT = os.path.expanduser('~/vietnamese-poem-generation')
sys.path.append(PROJECT_ROOT)
sys.path.insert(0, PROJECT_ROOT)
from constants import *

# %%
df = pd.read_csv(os.path.join(DATA_DIR, 'poem_dataset.csv'))
df
# Out:
#                                                   content  \
# 0       ngày đông se sắt lạnh trong lòng\ncó việc đi n...
# 1       ôm đàn thao thức đến nữa đêm\nréo rắt cung âm ...
# 2       tết có người vui có kẻ buồn\nngười cười toe to...
# 3       đã quá ba mươi mộng lỡ làng\nđi tìm day dứt mả...
# 4       mai đào nở rộ đón nàng xuân\nsợi nắng hanh vàn...
# ...                                                   ...
# 164324  Một trà, một rượu, một đàn bà,\nBa cái lăng nh...
# 164325  nghe được từ lâu cá thở than,\nhôm nay mới sõi...
# 164326  Nguyệt lão xe dây khéo vớ quàng\nXe người bạch...
# 164327  Danh chẳng tham mà lợi chẳng mê,\nẤy gang hay ...
# 164328  Được quyền sống nhung lụa\nNghĩ gì thân gió sư...
#
#                       title  \
# 0                  SAY NẮNG
# 1                       NaN
# 2          TẾT HAI THÁI CỰC
# 3       TRÁI NGANG ĐỨC HẠNH
# 4                 DÁNG XUÂN
# ...                     ...
# 164324    Ba cái lăng nhăng
# 164325    Ba chặng đường tu
# 164326     Bà Chiêu cải giá
# 164327       Bá Di, Thúc Tề
# 164328            Ba hữu lệ
#
#                                                       url  genre
# 0       https://www.facebook.com/groups/48640773509859...  7 chu
# 1       https://www.facebook.com/groups/17645444269765...  7 chu
# 2       https://www.facebook.com/groups/17645444269765...  7 chu
# 3       https://www.facebook.com/groups/48640773509859...  7 chu
# 4       https://www.facebook.com/groups/17645444269765...  7 chu
# ...                                                   ...    ...
# 164324  https://www.thivien.net/Tr%E1%BA%A7n-T%E1%BA%B...  7 chu
# 164325  https://www.thivien.net/V%C5%A9-Ho%C3%A0ng-Ch%...  7 chu
# 164326  https://www.thivien.net/Nh%C3%A0n-Khanh/B%C3%A...  7 chu
# 164327  https://www.thivien.net/T%C3%B4n-Th%E1%BB%8D-T...  7 chu
# 164328  https://www.thivien.net/Qu%C3%A1ch-T%E1%BA%A5n...  5 chu
#
# [164329 rows x 4 columns]

# %%
print(df['content'][100])
# Out:
# huế đợi anh đợi mãi anh ơi
# xuân gõ cửa đất trời thay đổi
# con sông quê nặng lòng vời vợi
# tiếng còi tàu vọng tới canh thâu
#
# huế đợi anh thấm đẫm dòng châu
# anh ở mô ôm sầu buồn lạnh
# giọt thương chờ hồn sâu hiu quạnh
# năm canh chày một mảnh tình đơn
#
# huế đợi anh réo rắc tủi hờn
# trái tim yêu sóng vờn mưa bụi
# có răng khôn hay tình lầm lũi
# em trông người xuân tới ghé thăm
#
# huế đợi anh đợi đến băn khoăn
# đêm buốt giá âm thầm đếm mộng
# mảnh trăng non không gian gió lộng
# gói đợi chờ mạch động niềm đau
#
# huế đợi anh đợi mãi ngàn sau
# hoài tuổi nhớ tình đầu ân ái
# rồi anh đi ngày dài xa mãi
# sợi nhớ nhung lắng lại khơi dòng
#
# huế đợi anh nắng hạ mưa đông
# đêm thổn thức ru lòng mãi đợi
# tia nắng mai khung trời dịu vợi
# xuân đã về huế đợi yêu anh
